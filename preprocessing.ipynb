# %%
import cv2
from matplotlib import pyplot as plt
image_file = "train/train/train/Invoice_1_affine_translation.jpg"
img = cv2.imread(image_file)

# %%
def display(im_path):
    dpi = 80
    im_data = plt.imread(im_path)

    height, width  = im_data.shape[:2]
    
    # What size does the figure need to be in inches to fit the image?
    figsize = width / float(dpi) , height / float(dpi)

    # Create a figure of the right size with one axes that takes up the full figure
    fig = plt.figure(figsize=figsize)
    ax = fig.add_axes([0, 0, 1, 1])

    # Hide spines, ticks, etc.
    ax.axis('off')

    # Display the image.
    ax.imshow(im_data, cmap='gray')

    plt.show()

# %%
display(image_file)

# %%
import pytesseract
from PIL import Image

# %%
img = Image.open("train/train/train/Invoice_1.jpg")

# %%
ocr_result = pytesseract.image_to_string(img)

# %%
print(ocr_result)
# Out:
# Sales Receipt
#
# BoostSclutions  roteyousiaepsine
#
# Nerateyeur sharers ite itr Ge Easier cma
#
# WASH tterratond Lies son aus
# Faitan Dwi lina PR Chine 0 AAC
#
# coe “sL0SaathJomeane
# hone: £610-62608152 730
# sales@bonesolorscon cusareriD 012062517
#
# S020
#
# Uni Price Discount
# sisssoo | 53138
# sizso | seus
#
# sesso | $59
#
# FouiDicaune| S513)
#
# ‘Subic
#
# Thank you for your business!
